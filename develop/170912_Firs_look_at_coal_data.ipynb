# %%
# Import needed libraries
# It nice a nice practice to keep all the imports at one single place
# First ensure that plots will be drown online
# %matplotlib inline

# Plotting library
import matplotlib.pyplot as plt

# Import DS usual library
import pandas as pd

# Import library that allows nice statistical graphics plotting
# and set its defaults params on
import seaborn as sns
sns.set()

# Import numpy to get extra functions
import numpy as np

# %%
# Build a pandas dataframe and fill it up with xls data
# The first 2 rows are dropped since data come after
# The column called "MSHA ID" is recognised as an ID and is placed first
df = pd.read_excel("../data/coalpublic2013.xls", header=2,index_col="MSHA ID")

# %%
df.head()
# Out:
#          Year                       Mine Name Mine State Mine County  \
# MSHA ID
# 103381   2013            Tacoa Highwall Miner    Alabama        Bibb
# 103404   2013                Reid School Mine    Alabama      Blount
# 100759   2013  North River #1 Underground Min    Alabama     Fayette
# 103246   2013                      Bear Creek    Alabama    Franklin
# 103451   2013                     Knight Mine    Alabama    Franklin
#
#                                 Mine Status    Mine Type  \
# MSHA ID
# 103381   Active, men working, not producing      Surface
# 103404                Permanently abandoned      Surface
# 100759   Active, men working, not producing  Underground
# 103246                               Active      Surface
# 103451                               Active      Surface
#
#                          Company Type              Operation Type  \
# MSHA ID
# 103381   Indepedent Producer Operator                   Mine only
# ...

# %%
# Check fields in a column with a given name, e.g. "Company Type"
Vcomptyp = df["Company Type"].unique()
Vcomptyp
# Out:
# array(['Indepedent Producer Operator', 'Operating Subsidiary', 'Contractor'], dtype=object)

# %%
type(Vcomptyp)
# Out:
# numpy.ndarray

# %%
# Correct a typo in the dataframe
# In column tagged: "Company Type"
# Rows with text: 'Indepedent Producer Operator'
# original text is replaced by: 'Independent Producer Operator'
# to correct the typo.
# The replacement is perfomed within the data frame thank to the option: inplace=True
df["Company Type"].replace(to_replace='Indepedent Producer Operator',
                          value='Independent Producer Operator',
                          inplace=True)

# %%
# See how the beginning of the column looks like in the data frame
df["Company Type"].head(n=10)
# Out:
# MSHA ID
# 103381    Independent Producer Operator
# 103404    Independent Producer Operator
# 100759    Independent Producer Operator
# 103246    Independent Producer Operator
# 103451    Independent Producer Operator
# 103433    Independent Producer Operator
# 100329             Operating Subsidiary
# 100851             Operating Subsidiary
# 102901    Independent Producer Operator
# 102901    Independent Producer Operator
# Name: Company Type, dtype: object

# %%
df["Average Employees"].head(n=10)
# Out:
# MSHA ID
# 103381     10
# 103404     18
# 100759    183
# 103246     13
# 103451     27
# 103433     27
# 100329     59
# 100851    447
# 102901      5
# 102901    571
# Name: Average Employees, dtype: int64

# %%
df["Labor Hours"].head(n=10)
# Out:
# MSHA ID
# 103381      22392
# 103404      28447
# 100759     474784
# 103246      29193
# 103451      46393
# 103433      47195
# 100329     144002
# 100851    1001809
# 102901      12396
# 102901    1237415
# Name: Labor Hours, dtype: int64

# %%
# Plot together 2 fields based on tags to index columns (solution 2, more explicit)
plt.scatter(df['Average Employees'],df['Labor Hours']) # Useful especially if tags contain spaces

# %%
# In the first row giving the name of each column,
# replace spaces: " " by "_".
# One uses a lambda function:
df.rename(columns=lambda x: x.replace(" ","_"),inplace=True)

# %%
# One can see that only first row is affected
df.head()
# Out:
#          Year                       Mine_Name Mine_State Mine_County  \
# MSHA ID
# 103381   2013            Tacoa Highwall Miner    Alabama        Bibb
# 103404   2013                Reid School Mine    Alabama      Blount
# 100759   2013  North River #1 Underground Min    Alabama     Fayette
# 103246   2013                      Bear Creek    Alabama    Franklin
# 103451   2013                     Knight Mine    Alabama    Franklin
#
#                                 Mine_Status    Mine_Type  \
# MSHA ID
# 103381   Active, men working, not producing      Surface
# 103404                Permanently abandoned      Surface
# 100759   Active, men working, not producing  Underground
# 103246                               Active      Surface
# 103451                               Active      Surface
#
#                           Company_Type              Operation_Type  \
# MSHA ID
# 103381   Independent Producer Operator                   Mine only
# ...

# %%
# Get size of the df, i.e. number of rows
len(df)
# Out:
# 1450

# %%
# Plot together 2 fields based on tags to index columns (solution1)
plt.scatter(df.Average_Employees,df.Labor_Hours)

# %%
# Plot together 2 fields based on tags to index columns (solution 2, more explicit)
plt.scatter(df['Average_Employees'],df['Labor_Hours']) # Useful especially if tags contain spaces
plt.xlabel("Number of employees")
plt.ylabel("Number of worked hours")

# %%
# Perform a linear regression plot based on these 2 columns by using seaborn
sns.regplot(df.Average_Employees,df['Labor_Hours'])
# Save the plot as an image
plt.savefig("../figures/170912_"+"Employees_vs_hours.png")

# %%
# Save the plot as an image

# %%
# Columns inspection:
# print all the tags in the header
cpt = 0
for column in df.columns:
    cpt+=1
    print("Column {}, tag: {}".format(cpt,column))

nbcols = len(df.columns)
print("There are {} columns.".format(nbcols))
# Out:
# Column 1, tag: Year
# Column 2, tag: Mine_Name
# Column 3, tag: Mine_State
# Column 4, tag: Mine_County
# Column 5, tag: Mine_Status
# Column 6, tag: Mine_Type
# Column 7, tag: Company_Type
# Column 8, tag: Operation_Type
# Column 9, tag: Operating_Company
# Column 10, tag: Operating_Company_Address
# Column 11, tag: Union_Code
# Column 12, tag: Coal_Supply_Region
# Column 13, tag: Production_(short_tons)
# Column 14, tag: Average_Employees
# Column 15, tag: Labor_Hours
# There are 15 columns.

# %%
df["Year"].head()
# Out:
# MSHA ID
# 103381    2013
# 103404    2013
# 100759    2013
# 103246    2013
# 103451    2013
# Name: Year, dtype: int64

# %%
df.Year.head()
# Out:
# MSHA ID
# 103381    2013
# 103404    2013
# 100759    2013
# 103246    2013
# 103451    2013
# Name: Year, dtype: int64

# %%
# New plot to see 2 different variables together
# NB Prduction... contains "(": it can only be addresse by using "text reference.
plt.scatter(df.Labor_Hours,df["Production_(short_tons)"])
plt.xlabel("Labor Hours")
plt.ylabel("Production (tons)")
plt.title("Corr between Hours and Production")

# %%
# Plot histogram for 1 variable
df["Production_(short_tons)"].hist()

# %%
df["Production_(short_tons)"].min()
# Out:
# 0

# %%
df["Production_(short_tons)"].max()
# Out:
# 111005549

# %%
df["Production_(short_tons)"].mean()
# Out:
# 679201.2268965517

# %%
# Plot histogram for 1 variable with more details
df["Production_(short_tons)"].hist(bins=100)

# %%
# Check where variable is equal to 0
df["Production_(short_tons)"] == 0
# Out:
# MSHA ID
# 103381     False
# 103404     False
# 100759     False
# 103246     False
# 103451     False
# 103433     False
# 100329      True
# 100851     False
# 102901      True
# 102901     False
# 103180     False
# 103182     False
# 103285     False
# 103332     False
# 103375     False
# 103419     False
# 103432     False
# 103437     False
# 102976      True
# 102976      True
# 103380      True
# 103380      True
# 103422     False
# 103467     False
# 101247     False
# 101401     False
# 103172     False
# 103179     False
# 103303     False
# 103323     False
#            ...
# 4801646    False
# 3304389    False
# 4407113    False
# 1100588    False
# 4605995    False
# 3608690    False
# 3608728    False
# 3609442    False
# 3603561    False
# 1518888    False
# 1519402    False
# 1519522    False
# 3604969    False
# 1519554    False
# 1519674    False
# 3608822    False
# 3609843    False
# 3610027    False
# 3609304    False
# 3609406    False
# 3609405    False
# ...

# %%
# In the data frame df, show only retains rows for which variable "Production_(short_tons)" is equal to 0
df[df["Production_(short_tons)"] == 0]
# Out:
#          Year                       Mine_Name                Mine_State  \
# MSHA ID
# 100329   2013                    Concord Mine                   Alabama
# 102901   2013                Shoal Creek Mine                   Alabama
# 102976   2013   Piney Woods Preparation Plant                   Alabama
# 102976   2013   Piney Woods Preparation Plant                   Alabama
# 103380   2013                          Calera                   Alabama
# 103380   2013                          Calera                   Alabama
# 103364   2013           Brc Alabama No. 7 Llc                   Alabama
# 103155   2013              Corinth Prep Plant                   Alabama
# 103155   2013              Corinth Prep Plant                   Alabama
# 504461   2013              New Elk Prep Plant                  Colorado
# 1103242  2013         Alliance Wor Processing                  Illinois
# 1103140  2013                   Cora Terminal                  Illinois
# ...

# %%
# In the data frame df, show only retains rows for which variable "Production_(short_tons)" is more than 0
df[df["Production_(short_tons)"] > 0]
# Out:
#          Year                       Mine_Name       Mine_State  \
# MSHA ID
# 103381   2013            Tacoa Highwall Miner          Alabama
# 103404   2013                Reid School Mine          Alabama
# 100759   2013  North River #1 Underground Min          Alabama
# 103246   2013                      Bear Creek          Alabama
# 103451   2013                     Knight Mine          Alabama
# 103433   2013              Crane Central Mine          Alabama
# 100851   2013                  Oak Grove Mine          Alabama
# 102901   2013                Shoal Creek Mine          Alabama
# 103180   2013             Sloan Mountain Mine          Alabama
# 103182   2013                        Fishtrap          Alabama
# 103285   2013                     Narley Mine          Alabama
# 103332   2013                   Powhatan Mine          Alabama
# 103375   2013                    Johnson Mine          Alabama
# 103419   2013               Maxine-Pratt Mine          Alabama
# ...

# %%
# Show corresponding number
len(df[df["Production_(short_tons)"] > 0])
# Out:
# 1061

# %%
# Reduce the size of the data frame by only keeping rows for which there indeed is a production bigger than 0
df = df[df["Production_(short_tons)"] > 0]
nbrDF=len(df)
print("Number of rows = {}.".format(nbrDF))
# Out:
# Number of rows = 1061.

# %%
# rePlot histogram for this new data frame for 1 variable with more details
df["Production_(short_tons)"].hist(bins=100)

# %%
# Take a look at the calculate the log of the production
np.log(df["Production_(short_tons)"]).head()
# Out:
# MSHA ID
# 103381    10.933178
# 103404    10.268374
# 100759    14.180234
# 103246    11.380388
# 103451    11.901577
# Name: Production_(short_tons), dtype: float64

# %%
# Create a new column in the data frame based on the log calculation and called "Log_Production"
df["Log_Production"] = np.log(df["Production_(short_tons)"])

# %%
df.head()
# Out:
#          Year                       Mine_Name Mine_State Mine_County  \
# MSHA ID
# 103381   2013            Tacoa Highwall Miner    Alabama        Bibb
# 103404   2013                Reid School Mine    Alabama      Blount
# 100759   2013  North River #1 Underground Min    Alabama     Fayette
# 103246   2013                      Bear Creek    Alabama    Franklin
# 103451   2013                     Knight Mine    Alabama    Franklin
#
#                                 Mine_Status    Mine_Type  \
# MSHA ID
# 103381   Active, men working, not producing      Surface
# 103404                Permanently abandoned      Surface
# 100759   Active, men working, not producing  Underground
# 103246                               Active      Surface
# 103451                               Active      Surface
#
#                           Company_Type              Operation_Type  \
# MSHA ID
# 103381   Independent Producer Operator                   Mine only
# ...

# %%
# Plot histogram of the newly built variable
# If the shape of the histogram is Gaussian, then this is a log normal distribution
df["Log_Production"].hist(bins=20)

# %%
# Export in a file the current version of the data frame
df.to_csv("../data/coalpublic2013_cleaned.csv")
